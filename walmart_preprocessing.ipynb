# %%
import pandas as pd

# %%
df = pd.read_csv("Walmart.csv")

# %%
df.columns
# Out:
# Index(['Store', 'Date', 'Weekly_Sales', 'Holiday_Flag', 'Temperature',
#        'Fuel_Price', 'CPI', 'Unemployment'],
#       dtype='object')

# %%
df.head(10)
# Out:
#    Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0      1  05/02/2010    1643690.90             0        42.31       2.572
# 1      1  12/02/2010    1641957.44             1        38.51       2.548
# 2      1  19/02/2010    1611968.17             0        39.93       2.514
# 3      1  26/02/2010    1409727.59             0        46.63       2.561
# 4      1  05/03/2010    1554806.68             0        46.50       2.625
# 5      1  12/03/2010    1439541.59             0        57.79       2.667
# 6      1  19/03/2010    1472515.79             0        54.58       2.720
# 7      1  26/03/2010    1404429.92             0        51.45       2.732
# 8      1  02/04/2010    1594968.28             0        62.27       2.719
# 9      1  09/04/2010    1545418.53             0        65.86       2.770
#
#           CPI  Unemployment
# 0  211.096358         8.106
# 1  211.242170         8.106
# 2  211.289143         8.106
# 3  211.319643         8.106
# ...

# %%
df.shape
# Out:
# (6435, 8)

# %%
df.tail(10)
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 6425     45  24/08/2012     718232.26             0        72.62       3.834
# 6426     45  31/08/2012     734297.87             0        75.09       3.867
# 6427     45  07/09/2012     766512.66             1        75.70       3.911
# 6428     45  14/09/2012     702238.27             0        67.87       3.948
# 6429     45  21/09/2012     723086.20             0        65.32       4.038
# 6430     45  28/09/2012     713173.95             0        64.88       3.997
# 6431     45  05/10/2012     733455.07             0        64.89       3.985
# 6432     45  12/10/2012     734464.36             0        54.47       4.000
# 6433     45  19/10/2012     718125.53             0        56.47       3.969
# 6434     45  26/10/2012     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# 6425  191.344887         8.684
# 6426  191.461281         8.684
# ...

# %%
df.sample(4)
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 1441     11  23/04/2010    1283766.55             0        68.37       2.795
# 860       7  19/02/2010     506760.54             0        27.28       2.550
# 1521     11  04/11/2011    1458287.38             0        61.13       3.332
# 1386     10  30/12/2011    1930690.37             1        48.92       3.428
#
#              CPI  Unemployment
# 1441  213.722185         7.343
# 860   189.534100         9.014
# 1521  221.245968         7.197
# 1386  130.071032         7.874

# %%
df.columns
# Out:
# Index(['Store', 'Date', 'Weekly_Sales', 'Holiday_Flag', 'Temperature',
#        'Fuel_Price', 'CPI', 'Unemployment'],
#       dtype='object')

# %%
df.rename(columns={"Embarked":"Onboard","Cabin":"First_Cabin","Ticket":"Our_Tickets"},inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6435 entries, 0 to 6434
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         6435 non-null   int64
#  1   Date          6435 non-null   object
#  2   Weekly_Sales  6435 non-null   float64
#  3   Holiday_Flag  6435 non-null   int64
#  4   Temperature   6435 non-null   float64
#  5   Fuel_Price    6435 non-null   float64
#  6   CPI           6435 non-null   float64
#  7   Unemployment  6435 non-null   float64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 402.3+ KB

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1  05/02/2010    1643690.90             0        42.31       2.572
# 1         1  12/02/2010    1641957.44             1        38.51       2.548
# 2         1  19/02/2010    1611968.17             0        39.93       2.514
# 3         1  26/02/2010    1409727.59             0        46.63       2.561
# 4         1  05/03/2010    1554806.68             0        46.50       2.625
# ...     ...         ...           ...           ...          ...         ...
# 6430     45  28/09/2012     713173.95             0        64.88       3.997
# 6431     45  05/10/2012     733455.07             0        64.89       3.985
# 6432     45  12/10/2012     734464.36             0        54.47       4.000
# 6433     45  19/10/2012     718125.53             0        56.47       3.969
# 6434     45  26/10/2012     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# ...

# %%
df.isnull().sum()
# Out:
# Store           0
# Date            0
# Weekly_Sales    0
# Holiday_Flag    0
# Temperature     0
# Fuel_Price      0
# CPI             0
# Unemployment    0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Store           0
# Date            0
# Weekly_Sales    0
# Holiday_Flag    0
# Temperature     0
# Fuel_Price      0
# CPI             0
# Unemployment    0
# dtype: int64

# %%
df.head(4)
# Out:
#    Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0      1  05/02/2010    1643690.90             0        42.31       2.572
# 1      1  12/02/2010    1641957.44             1        38.51       2.548
# 2      1  19/02/2010    1611968.17             0        39.93       2.514
# 3      1  26/02/2010    1409727.59             0        46.63       2.561
#
#           CPI  Unemployment
# 0  211.096358         8.106
# 1  211.242170         8.106
# 2  211.289143         8.106
# 3  211.319643         8.106

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6435 entries, 0 to 6434
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         6435 non-null   int64
#  1   Date          6435 non-null   object
#  2   Weekly_Sales  6435 non-null   float64
#  3   Holiday_Flag  6435 non-null   int64
#  4   Temperature   6435 non-null   float64
#  5   Fuel_Price    6435 non-null   float64
#  6   CPI           6435 non-null   float64
#  7   Unemployment  6435 non-null   float64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 402.3+ KB

# %%
df.describe()
# Out:
#              Store  Weekly_Sales  Holiday_Flag  Temperature   Fuel_Price  \
# count  6435.000000  6.435000e+03   6435.000000  6435.000000  6435.000000
# mean     23.000000  1.046965e+06      0.069930    60.663782     3.358607
# std      12.988182  5.643666e+05      0.255049    18.444933     0.459020
# min       1.000000  2.099862e+05      0.000000    -2.060000     2.472000
# 25%      12.000000  5.533501e+05      0.000000    47.460000     2.933000
# 50%      23.000000  9.607460e+05      0.000000    62.670000     3.445000
# 75%      34.000000  1.420159e+06      0.000000    74.940000     3.735000
# max      45.000000  3.818686e+06      1.000000   100.140000     4.468000
#
#                CPI  Unemployment
# count  6435.000000   6435.000000
# mean    171.578394      7.999151
# std      39.356712      1.875885
# min     126.064000      3.879000
# 25%     131.735000      6.891000
# 50%     182.616521      7.874000
# 75%     212.743293      8.622000
# max     227.232807     14.313000

# %%
a = df.describe(include = "all")

# %%
a
# Out:
#               Store        Date  Weekly_Sales  Holiday_Flag  Temperature  \
# count   6435.000000        6435  6.435000e+03   6435.000000  6435.000000
# unique          NaN         143           NaN           NaN          NaN
# top             NaN  05/02/2010           NaN           NaN          NaN
# freq            NaN          45           NaN           NaN          NaN
# mean      23.000000         NaN  1.046965e+06      0.069930    60.663782
# std       12.988182         NaN  5.643666e+05      0.255049    18.444933
# min        1.000000         NaN  2.099862e+05      0.000000    -2.060000
# 25%       12.000000         NaN  5.533501e+05      0.000000    47.460000
# 50%       23.000000         NaN  9.607460e+05      0.000000    62.670000
# 75%       34.000000         NaN  1.420159e+06      0.000000    74.940000
# max       45.000000         NaN  3.818686e+06      1.000000   100.140000
#
#          Fuel_Price          CPI  Unemployment
# ...

# %%
a.loc[["top","mean"]]
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# top     NaN  05/02/2010           NaN           NaN          NaN         NaN
# mean   23.0         NaN  1.046965e+06       0.06993    60.663782    3.358607
#
#              CPI  Unemployment
# top          NaN           NaN
# mean  171.578394      7.999151

# %%
a.iloc[[1,3,5]]
# Out:
#             Store Date   Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# unique        NaN  143            NaN           NaN          NaN         NaN
# freq          NaN   45            NaN           NaN          NaN         NaN
# std     12.988182  NaN  564366.622054      0.255049    18.444933     0.45902
#
#               CPI  Unemployment
# unique        NaN           NaN
# freq          NaN           NaN
# std     39.356712      1.875885

# %%
df.columns
# Out:
# Index(['Store', 'Date', 'Weekly_Sales', 'Holiday_Flag', 'Temperature',
#        'Fuel_Price', 'CPI', 'Unemployment'],
#       dtype='object')

# %%
df["Weekly_Sales"].value_counts().plot(kind="bar",title="Weekly_Sales",color="purple")
# Out:
# <Axes: title={'center': 'Weekly_Sales'}, xlabel='Weekly_Sales'>

# %%
df["Weekly_Sales"].value_counts().plot(kind="line",title="Weekly_Sales",color="purple")
# Out:
# <Axes: title={'center': 'Weekly_Sales'}, xlabel='Weekly_Sales'>

# %%
df.isnull().sum()
# Out:
# Store           0
# Date            0
# Weekly_Sales    0
# Holiday_Flag    0
# Temperature     0
# Fuel_Price      0
# CPI             0
# Unemployment    0
# dtype: int64

# %%
df[df["Temperature"].isnull()]
# Out:
# Empty DataFrame
# Columns: [Store, Date, Weekly_Sales, Holiday_Flag, Temperature, Fuel_Price, CPI, Unemployment]
# Index: []

# %%
df["Weekly_Sales"]=df["Fuel_Price"].fillna(df["CPI"].mean())

# %%
df[df["Weekly_Sales"].isnull()]
# Out:
# Empty DataFrame
# Columns: [Store, Date, Weekly_Sales, Holiday_Flag, Temperature, Fuel_Price, CPI, Unemployment]
# Index: []

# %%
df.groupby
# Out:
# <bound method DataFrame.groupby of       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1  05/02/2010         2.572             0        42.31       2.572
# 1         1  12/02/2010         2.548             1        38.51       2.548
# 2         1  19/02/2010         2.514             0        39.93       2.514
# 3         1  26/02/2010         2.561             0        46.63       2.561
# 4         1  05/03/2010         2.625             0        46.50       2.625
# ...     ...         ...           ...           ...          ...         ...
# 6430     45  28/09/2012         3.997             0        64.88       3.997
# 6431     45  05/10/2012         3.985             0        64.89       3.985
# 6432     45  12/10/2012         4.000             0        54.47       4.000
# 6433     45  19/10/2012         3.969             0        56.47       3.969
# 6434     45  26/10/2012         3.882             0        58.85       3.882
#
# ...

# %%
df.to_csv("data2.csv")
